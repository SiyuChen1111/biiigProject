# %% [markdown]
# # ANN training on CPP epoch exports

# %%
from cpp_ann import run_ann_training
from cpp_paths import ANN_OUTPUT_ROOT, CPP_OUTPUT_ROOT, ensure_output_dirs

ensure_output_dirs()
artifacts = run_ann_training(CPP_OUTPUT_ROOT, ANN_OUTPUT_ROOT)
artifacts

# %%
import pandas as pd

metrics = pd.read_csv(artifacts['metrics_csv'])
predictions = pd.read_csv(artifacts['predictions_csv'])
metrics, predictions.head()
